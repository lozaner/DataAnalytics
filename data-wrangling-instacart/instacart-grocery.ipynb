# %% [markdown]
# # ¡Hola Elpidio!
#
# Mi nombre es Ezequiel Ferrario, soy code reviewer en Tripleten y tengo el agrado de revisar el proyecto que entregaste.
#
# Para simular la dinámica de un ambiente de trabajo, si veo algún error, en primer instancia solo los señalaré, dándote la oportunidad de encontrarlos y corregirlos por tu cuenta. En un trabajo real, el líder de tu equipo hará una dinámica similar. En caso de que no puedas resolver la tarea, te daré una información más precisa en la próxima revisión.
#
# Encontrarás mis comentarios más abajo - **por favor, no los muevas, no los modifiques ni los borres**.
#
# ¿Cómo lo voy a hacer? Voy a leer detenidamente cada una de las implementaciones que has llevado a cabo para cumplir con lo solicitado. Verás los comentarios de esta forma:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si todo está perfecto.
# </div>
#
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta. Se aceptan uno o dos comentarios de este tipo en el borrador, pero si hay más, deberá hacer las correcciones. Es como una tarea de prueba al solicitar un trabajo: muchos pequeños errores pueden hacer que un candidato sea rechazado.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# hola ezequiel muchas gracias por la revision y por los comentarios ya que cuando lo mande por primera vez no sabia si iba bien y ya me estaba desmotivando porque la parte C de plano no le entendia ni la logica pero entre su ayuda con sus comentarios de las pistas y la ayuda de los maestros en el co learning me ayudaron de mucho este proyecto fue el mas completo utilice muchos metos que habia estudiado en lectura y que no sabia como realmente se utilizaban asi como la logica de que es lo que se utulizaria para los datos y te doy las gracias por la revision y la subida de animo en esos comentarios que pusiste ya corregi en el .info(show_counts = True) que la verdad no notaba la diferencia hasta que me explico la maestra irene porque solo se ve la diferencia en uno y ya respondi un comentario que hiciste sobre los 64 productos gracias de nuevo y nos vemos pronto para el siguiente proyecto primero Dios saludos y exito.
#
#
# P.D.: si tienes informacion de como hacer estos cuadritos me gustaria aprender creo me serviri mas despues para hacer mis anotaciones cuando trabaje.
# </div>
#
# ¡Empecemos!

# %% [markdown]
# -----------
#
# <div class="alert alert-block alert-danger">
# <b>Comentario general #1</b> <a class="tocSkip"></a>
#
# Elpidio, has realizado un buen trabajo aqui y te manejaste muy bien con todos los puntos.
#
#  Me  encanto la limpieza que hiciste con los datos y luegos los graficos realizados.
#
#   Te manejaste muy bien con el codigo y cuando dejaste tus observaciones fueron muy buenas tambien.
#
#  Asi, te deje una guia de como continuar. Has hecho un muy buen proyecto.
#
#   Espero tu correccion, saludos.
#
# </div>
#
#
#
# -------------
# <div class="alert alert-block alert-success">
# <b>Comentario general #2</b> <a class="tocSkip"></a>
#
# Elpidio, las correcciones fueron perfectas.
#
#  Finalizaste asi la limpieza de los datos con las conclusiones que faltaban y luego  las extracciones del punto C fueron muy buenas.
#
#   Los nuevos graficos generados estuvieron bien realizados y asi completas un gran proyecto.
#
#   Por lo dicho, el mismo pasa a estar **aprobado**.
#
#   Exitos en lo que viene, saludos.
#
# </div>
#
# --------

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy bien creando una tabla de contenidos.
#
#
# </div>

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.

# %%
# importar librerías
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# leer conjuntos de datos en los DataFrames
instacart_orders = pd.read_csv('/datasets/instacart_orders.csv',sep=";")
products= pd.read_csv('/datasets/products.csv', sep= ';')
aisles = pd.read_csv('/datasets/aisles.csv',sep=';')
departaments=pd.read_csv('/datasets/departments.csv',sep=';')
order_products=pd.read_csv('/datasets/order_products.csv', sep=';')

# %%
# mostrar información del DataFrame
instacart_orders.info(show_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %%
# mostrar información del DataFrame
products.info(show_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Realiza el metodo info() en este dataset.
#
# </div>
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, muy bien.
#
# </div>

# %%
# mostrar información del DataFrame
aisles.info(show_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Realiza el metodo info() en este dataset.
#
# </div>
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.
#
# </div>

# %%
# mostrar información del DataFrame
departaments.info(show_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes

# %%
# mostrar información del DataFrame
order_products.info(show_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Realiza el metodo info() en este dataset.
#
# En este caso (para este dataframe) deberias utilizar el parametro show_counts = True para que el metodo te arroje los datos correspondientes (De los no nulos).
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido. Aqui no se observan los valores ya que debes utilizar el paraemtro show_counts en True dentro del info()
# </div>

# %% [markdown]
# ## Conclusiones
#
# Lo primero que hicimos fue importar la libreria pandas con la variable pd y la libreria numpy con la variable np que ocuparemos tal vez despues tambien leimos los datos de cada archivo csv que ocuparemos y le asignamos nombre de variable para cada archivo asi como le quitamos ; que nos impedia a la visualizacion de la grafica.

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %%
#los metodos que usaremos son los siguientes:
    
#.to_numeric() para convertir a numeros enteros
#.isna().sum() deteccion de valores ausente
#.fillna()  remplazar valores ausente
#.duplicated() identificar duplicados
#.duplicated().sum() sumar los duplicados
#.drop_duplicates() eliminar duplicados
#.inplace=True modifica el df original
#.reset_index() resetea el indice de la tabla

# %% [markdown]
# ## Plan de solución
#
# Ahora verificaremos y limpiaremos el archivo para su analisis veremos que las columnas de ID sea numeros enteros y sino coregirlos para que sean enteros, buscaremos si hay datos ausentes y completarlos asi como identificar si hay valores duplicados y eliminarlos, limpiaremos todo los archivos para que se haga un analisis correcto.

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `instacart_orders` data frame

# %%
# Revisa si hay pedidos duplicados
instacart_orders.duplicated().sum()
# Out:
# 15

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.

# %%
instacart_orders[instacart_orders.duplicated()]
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# 371905    391768    57671            19          3                  2
# 394347    467134    63189            21          3                  2
# ...

# %%
wednesday=instacart_orders[(instacart_orders['order_dow']==3) & (instacart_orders['order_hour_of_day']==2)]

wednesday
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 4838                      16.0
# 5156                      11.0
# ...

# %% [markdown]
# ¿Qué sugiere este resultado?

# %%
# Elimina los pedidos duplicados

instacart_orders=instacart_orders.drop_duplicates()

# %%
# Vuelve a verificar si hay filas duplicadas
instacart_orders.duplicated().sum()
# Out:
# 0

# %%
# Vuelve a verificar si hay IDs duplicados de pedidos
duplicados_id = instacart_orders['order_id'].duplicated().sum()
print(f"Número de duplicados en la columna'order_id': {duplicados_id}")
# Out:
# Número de duplicados en la columna'order_id': 0

# %% [markdown]
# buscamos en instacart_orders si habia algun duplicado y salieron 15 datos y tambien revisamos los pedidos del miercoles a las 2am ya que a simple vista se veia que los datos duplicados eran del miercoles a las 2am de los cuales encontramos 121 datos entonces seguimos a eliminar los duplicados y se reviso que ya no hubiera duplicado revisamos que no ubiera duplicados en 'order_id' y yambien ya no se encontraron mas duplicados.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Describi y conclui al respecto de lo realizado en en esta seccion. Esta parte es muy importante debido que es aqui donde tambien esta nuestro valor, ya que muchos podran no entender el codigo pero si el analisis o la descripcion.</div>
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, muy buenas observaciones.
#
# </div>

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
products.duplicated().sum()
# Out:
# 0

# %%
# Verifica si hay IDs duplicadas de productos
duplicados_products = products['product_id'].duplicated().sum()
print(f"Número de duplicados en la columna'product_id': {duplicados_products}")
# Out:
# Número de duplicados en la columna'product_id': 0

# %%
# Revisa si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
products['product_name'] = products['product_name'].str.upper()
print(f"Número de duplicados en la columna 'product_name': {duplicados_products.sum()}\n")


products[products['product_name'].duplicated()==True]
# Out:
# Número de duplicados en la columna 'product_name': 0
#        product_id                                     product_name  aisle_id  \
# 71             72                                              NaN       100
# 109           110                                              NaN       100
# 296           297                                              NaN       100
# 416           417                                              NaN       100
# 436           437                                              NaN       100
# ...           ...                                              ...       ...
# 49689       49690                    HIGH PERFORMANCE ENERGY DRINK        64
# 49690       49691                    ORIGINAL PANCAKE & WAFFLE MIX       130
# 49691       49692  ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR       130
# 49692       49693                           SPRING WATER BODY WASH       127
# ...

# %%
duplicados_products
# Out:
# 0

# %%
# Revisa si hay nombres duplicados de productos no faltantes
products[(products['product_name'].duplicated()== True) & (products['product_name'].isna()==False)]
# Out:
#        product_id                                     product_name  aisle_id  \
# 2058         2059                                  BIOTIN 1000 MCG        47
# 5455         5456                 GREEN TEA WITH GINSENG AND HONEY        96
# 5558         5559                           CREAM OF MUSHROOM SOUP        69
# 7558         7559                        CINNAMON ROLLS WITH ICING       105
# 9037         9038                           AMERICAN CHEESE SLICES        21
# ...           ...                                              ...       ...
# 49689       49690                    HIGH PERFORMANCE ENERGY DRINK        64
# 49690       49691                    ORIGINAL PANCAKE & WAFFLE MIX       130
# 49691       49692  ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR       130
# 49692       49693                           SPRING WATER BODY WASH       127
# 49693       49694                          BURRITO- STEAK & CHEESE        38
#
#        department_id
# 2058              11
# ...

# %%
#Contar el número de duplicados no faltantes

products[(products['product_name'].duplicated()== True) & (products['product_name'].isna()==True)].count()
# Out:
# product_id       1257
# product_name        0
# aisle_id         1257
# department_id    1257
# dtype: int64

# %% [markdown]
# buscamos si se encontraban duplicados en el archivo products y no se encontro se encontraron ausentes pero a simple vista duplicados no entonces buscamos cambiando el nombre de producto a un solo formato de string que fueran en mayusculas despues buscaron duplicados no faltantes osea los valores que no son ausentes y seguimos buscando si en alguna otra columna encontraba alguna columna con valores duplicados y valores no faltantes y en ninguna los encontramos.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Describi y conclui al respecto de lo realizado en en esta seccion. Esta parte es muy importante debido que es aqui donde tambien esta nuestro valor, ya que muchos podran no entender el codigo pero si el analisis o la descripcion.</div>
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, muy bien.
#
# </div>

# %% [markdown]
# ### `departaments` data frame

# %%
# Revisa si hay filas totalmente duplicadas
departaments.duplicated().sum()
# Out:
# 0

# %%
# Revisa si hay IDs duplicadas de productos
duplicados_departaments = departaments['department_id'].duplicated().sum()
print(f"Número de duplicados en la columna'department_id': {duplicados_departaments}")
# Out:
# Número de duplicados en la columna'department_id': 0

# %% [markdown]
# seguimos buscando duplicados en el archivo departaments y tampoco se encontro valores duplicados

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Describi y conclui al respecto de lo realizado en en esta seccion. Esta parte es muy importante debido que es aqui donde tambien esta nuestro valor, ya que muchos podran no entender el codigo pero si el analisis o la descripcion.</div>
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.
#
# </div>

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
aisles.duplicated().sum()
# Out:
# 0

# %%
# Revisa si hay IDs duplicadas de productos
duplicados_aisles = aisles['aisle_id'].duplicated().sum()
print(f"Número de duplicados en la columna'order_id': {duplicados_aisles}")
# Out:
# Número de duplicados en la columna'order_id': 0

# %% [markdown]
# hicimos lo mismo con el archivo de los pasillos y tambien no se encontro ninguna duplicado.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Describi y conclui al respecto de lo realizado en en esta seccion. Esta parte es muy importante debido que es aqui donde tambien esta nuestro valor, ya que muchos podran no entender el codigo pero si el analisis o la descripcion.</div>
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.
#
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
order_products.duplicated().sum()
# Out:
# 0

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
order_products[order_products.duplicated(subset=['order_id','product_id'])]

#no hay duplicados engañosos
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %% [markdown]
# aqui se hizo lo mismo buscar duplicados en el archivo de order_products de los cuales no se encontro ningun duplicado despues no dijeron que veriricaramos algun duplicado engañoso lo cual no se encontro.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Describi y conclui al respecto de lo realizado en en esta seccion. Esta parte es muy importante debido que es aqui donde tambien esta nuestro valor, ya que muchos podran no entender el codigo pero si el analisis o la descripcion.</div>
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.
#
# </div>

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
ausentes_product_name = products['product_name'].isna().sum()
print(ausentes_product_name)
# Out:
# 1258

# %%
nan_products=products[products['product_name'].isna()]
print(nan_products)
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# vemos que hay 1258 valores ausente en la columna de product_name y al parecer tienen en comun el pasillo id 100 y department_id 21 asi que se tendria que remplazar Nan con desconocido para poder sacar nuestro analisis.

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
nan_products=products[products['product_name'].isna()]

print(nan_products['aisle_id'].unique())
# Out:
# [100]

# %% [markdown]
# buscamos los datos ausentes de 'product_name' y despues buscamos si los datos ausentes estaban relacionado con algun 'aisle_id y salio que efectivamente estaba relacionado con 100 unico valor.

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?

print(nan_products['department_id'].unique())
# Out:
# [21]

# %% [markdown]
# tiene la misma coinsidencia que aisle_id solo coinsidian los valores ausentes con un unico 'department_id'

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.
print(aisles[aisles['aisle_id']==100])
print(departaments[departaments['department_id']==21])
# Out:
#     aisle_id    aisle
# 99       100  missing
#     department_id department
# 20             21    missing

# %% [markdown]
# entonces buscamos en el archivo aisles y la columna 'aisle_id' con que dato esta relacionado ese pasillo y salio missing lo que quiero pensar es que reordenaron el pasillo y lo mismo hicimos con el archivo department columna department_id lo cual arrojo missing que se piensa que son articulos caducas, tambien puede ser que ese numero de departamento y pasillo esten en reparacion o algo este pasando desconocido seria preguntar.

# %%
# Completa los nombres de productos ausentes con 'Unknown'
products['product_name']= products['product_name'].fillna('Unknown')
print(products)

print(products[products['product_name'] == 'Unknown'])
print()

print(products['product_name'].isna().sum())
# Out:
#        product_id                                       product_name  \
# 0               1                         CHOCOLATE SANDWICH COOKIES
# 1               2                                   ALL-SEASONS SALT
# 2               3               ROBUST GOLDEN UNSWEETENED OOLONG TEA
# 3               4  SMART ONES CLASSIC FAVORITES MINI RIGATONI WIT...
# 4               5                          GREEN CHILE ANYTIME SAUCE
# ...           ...                                                ...
# 49689       49690                      HIGH PERFORMANCE ENERGY DRINK
# 49690       49691                      ORIGINAL PANCAKE & WAFFLE MIX
# 49691       49692    ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR
# 49692       49693                             SPRING WATER BODY WASH
# 49693       49694                            BURRITO- STEAK & CHEESE
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# ...

# %% [markdown]
# revisamos si habia datos ausentes y encontramos 1258 y los remplazamos con 'Unknown' depues revise para que se viera si los habia remplazado y volvi a revisar si habia algun dato ausente y ya salio 0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Excelente entendiendo el patron e estos nulos.
#
# </div>

# %% [markdown]
# ### `orders` data frame

# %%
# Encuentra los valores ausentes
ausentes_instacart_orders = instacart_orders.isna().sum()
print(ausentes_instacart_orders)
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
filtrado_instacart_orders= instacart_orders[instacart_orders['days_since_prior_order'].isna()]
print(filtrado_instacart_orders)
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 28        133707   182261             1          3                 10
# 96        787445    25685             1          6                 18
# 100       294410   111449             1          0                 19
# 103      2869915   123958             1          4                 16
# 104      2521921    42286             1          3                 18
# ...          ...      ...           ...        ...                ...
# 478895   2589657   205028             1          0                 16
# 478896   2222353   141211             1          2                 13
# 478922   2272807   204154             1          1                 15
# 478926   2499542    68810             1          4                 19
# 478945   1387033    22496             1          5                 14
#
#         days_since_prior_order
# 28                         NaN
# 96                         NaN
# ...

# %%
instacart_orders
print(filtrado_instacart_orders['order_number'].unique())
# Out:
# [1]

# %% [markdown]
# nos damos cuenta que en la columna 'days_since_prior_order' hay 28817 datos ausentes y revisamos que si los datos ausentes coinsidian con el primer pedido y se reviso que valores unicos tenia la columna de 'order_number' ya con la variable que se creo revisando los valores ausentes se reviso si la columna 'order_number' tenia otro valor y no fue solo ese valor asi que si todos los valores ausentes corresponden ala primera orden.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
#   Muy bien entendiendo estos nulos.
#
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
# Encuentra los valores ausentes
ausentes_order_products = order_products.isna().sum()
print(ausentes_order_products)
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?
print(f"El valor maximo son : ")
print(order_products.max())
# Out:
# El valor maximo son :
# order_id             3421079.0
# product_id             49694.0
# add_to_cart_order         64.0
# reordered                  1.0
# dtype: float64

# %%
print(f"El valor minimo son: ")
print(order_products.min())
# Out:
# El valor minimo son:
# order_id             4.0
# product_id           1.0
# add_to_cart_order    1.0
# reordered            0.0
# dtype: float64

# %% [markdown]
# En el archivo order_products encontramos valores ausente en add_to_cart_order que son 836 valores ausentes y revisamos cual es el valor maximo de esa columna que es 64 productos que se añadio en el carrito y el valor minimo es 1.

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'
filtrado_order_products = order_products[order_products['add_to_cart_order'].isna()]
filtrado_order_id = filtrado_order_products['order_id'].drop_duplicates()
print(filtrado_order_id)
# Out:
# 737        2449164
# 9926       1968313
# 14394      2926893
# 16418      1717990
# 30114      1959075
#             ...
# 2437093       9310
# 2438301    2170451
# 3275635    2979697
# 3282194    1625713
# 3357079    1529171
# Name: order_id, Length: 70, dtype: int64

# %%
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
group_order_products = order_products[order_products['order_id'].isin(filtrado_order_id)]

agrupar = group_order_products.groupby('order_id')['product_id'].count().reset_index()
print(agrupar)
# Out:
#     order_id  product_id
# 0       9310          65
# 1      61355         127
# 2     102236          95
# 3     129627          69
# 4     165801          70
# ..       ...         ...
# 65   2999801          70
# 66   3125735          86
# 67   3308010         115
# 68   3347453          71
# 69   3383594          69
#
# [70 rows x 2 columns]

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 producto
agrupar[agrupar['product_id']>=64].count()
# Out:
# order_id      70
# product_id    70
# dtype: int64

# %%
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.
print(group_order_products.count().min())
print()
print(group_order_products.count().max())
# Out:
# 4480
#
# 5316

# %% [markdown]
# filtramos en una variable todas las ordenes con valores ausente para despues guardarlos en una variable con orden Ids y eliminamos duplicados que ubiera quedando 70 valores ausentes ausentes y agrupamos los pedidos por datos ausentes con la variable creada de los ids de ordenes y agrupamos orden_id y product_id para hacer solo una tabla y los contamos para saber cuantos productos tenia cada ordenes despues seguimos buscando si los valores ausentes tenian mas de 64 productos y la respues fue si los valores ausentes tienen mas de 64 productos tienen 70 sacamos tambien cual era el numero maximo de productos en cada orden y minimos.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor </b> <a class="tocSkip"></a>
#
# En razon de la pregunta si `¿Todos los pedidos con valores ausentes tienen más de 64 productos?`
#
# Podes buscar las `order_id` que tienen valores ausentes en la columna 'add_to_cart_order'.
#
# Después de identificar los IDs -unicos- de pedidos con valores ausentes, asegúrate de filtrar el DataFrame original para incluir solo las filas correspondientes a esos IDs de pedidos antes de realizar la agrupación (Verifica que se encuentren en el primer filtrado los datos). Esto asegurará que estás trabajando solo con los datos relevantes. (Como consejo utiliza en la agrupacion la id de orden pero utilizando el metodo unique para depurar)
#
# Al calcular la cantidad mínima de productos, asegúrate de que estás obteniendo la cantidad mínima de productos en un solo pedido con valores ausentes, no la cantidad mínima entre todos los pedidos agrupados. Revisa cómo estás aplicando la función de conteo y la función de mínimo para obtener el resultado correcto.
# </div>
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.
#
# </div>

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart_order' con 999 y convierte la columna al tipo entero.
order_products['add_to_cart_order']=order_products['add_to_cart_order'].fillna(999)
print(order_products)

print(order_products[order_products['add_to_cart_order']== 999])
print()
print(order_products['add_to_cart_order'].isna().sum())
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 0         2141543       11440               17.0          0
# 1          567889        1560                1.0          1
# 2         2261212       26683                1.0          1
# 3          491251        8670               35.0          1
# 4         2571142        1940                5.0          1
# ...           ...         ...                ...        ...
# 4545002    577211       15290               12.0          1
# 4545003   1219554       21914                9.0          0
# 4545004    692640       47766                4.0          1
# 4545005    319435         691                8.0          1
# 4545006   1398151       28733                9.0          0
#
# [4545007 rows x 4 columns]
#          order_id  product_id  add_to_cart_order  reordered
# 737       2449164        5068              999.0          0
# 9926      1968313       43867              999.0          0
# ...

# %% [markdown]
# ya que encontramos datos ausentes Nan en 'add_to_cart_order' los remplazaremos con 999 y revisamos si seguian habiendo datos ausente que ya salio 0 siendo 836 datos que se remplazaron con ese valor

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# ¿Por que crees que el maximo de `add_to_cart_order` se detiene en 64? ¿No crees que es un valor muy arbitrario?</div>
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, muy bien.
#
# </div>

# %% [markdown]
# En rel registro solo llega a marcar como maximo 64 sin embargo en los analisis dice que llega a tener hasta 70 productos lo que tiene que investigarse que esta pasando cuando despues del 64 ya que si hay mas productos cargados en el carrito solo que sale el dato ausente.

# %% [markdown]
# ## Conclusiones
#
# en conclusion limpiamos cada una de los archivo y cada una de la columna remplazando datos ausentes y eliminando duplicados y revisando datos para ver si de alguna otra forma se encontraban datos engañosos que necesita remplazar o eliminar y pues con todo lo que hicimos ya podemos empezar a analizar.

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
print(instacart_orders['order_hour_of_day'].describe())
# Out:
# count    478952.000000
# mean         13.447034
# std           4.224567
# min           0.000000
# 25%          10.000000
# 50%          13.000000
# 75%          16.000000
# max          23.000000
# Name: order_hour_of_day, dtype: float64

# %%
print(instacart_orders['order_dow'].describe())
# Out:
# count    478952.000000
# mean          2.775051
# std           2.045901
# min           0.000000
# 25%           1.000000
# 50%           3.000000
# 75%           5.000000
# max           6.000000
# Name: order_dow, dtype: float64

# %% [markdown]
# verificamos los valores sensibles para saber cuales ocupariamos para las horas y los dias se ocupo describe para saber el valor minimo y maximo asi como cual es la media de la hora promedio y la media de las dias que se ocupan mas en este proyecto.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# En este caso estas observando los valores minimos y maximos, sin saber cuales son los valores medios.
#
# Constatando los valores unicos observaremos el panorama completo ya que de esta forma no podemos ver si los valores medios son congruentes.</div>
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, muy bien.
#
# </div>

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
grupby_instacart_orders=instacart_orders.groupby('order_hour_of_day')['user_id'].nunique().reset_index()

grupby_instacart_orders.plot(title='Usuario por hora',
                      x='order_hour_of_day',
                      y='user_id',
                      kind='bar',
                      xlabel='Horas',
                      ylabel='Usuarios',
                      legend=False )

plt.show()

# %% [markdown]
# lo que visualizamos es que la mayoria de las personas hacen su despensa de 10 a las 16 hrs

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Buen grafico.
#
# </div>

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
grupby_dias_id=instacart_orders.groupby('order_dow')['user_id'].nunique().reset_index()
print(grupby_dias_id)
# Out:
#    order_dow  user_id
# 0          0    57661
# 1          1    56479
# 2          2    48587
# 3          3    45331
# 4          4    44281
# 5          5    46127
# 6          6    45604

# %%
grupby_dias_id.plot(title='ordenes por dia de la semana',
                      x='order_dow',
                      y='user_id',
                      kind='bar',
                      xlabel='dias de la semana',
                      ylabel='cantidad e ordenes',
                      legend=False )

plt.show()

# %% [markdown]
# La mayoria de los usuarios compran su despensa los domingos y los lunes.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy bien .
#
#
# </div>

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
grupby_order_people=instacart_orders.groupby('days_since_prior_order')['order_number'].count()
print(grupby_order_people)
# Out:
# days_since_prior_order
# 0.0      9589
# 1.0     20179
# 2.0     27138
# 3.0     30224
# 4.0     31006
# 5.0     30096
# 6.0     33930
# 7.0     44577
# 8.0     25361
# 9.0     16753
# 10.0    13309
# 11.0    11467
# 12.0    10658
# 13.0    11737
# 14.0    13992
# 15.0     9416
# 16.0     6587
# 17.0     5498
# 18.0     4971
# 19.0     4939
# 20.0     5302
# 21.0     6448
# 22.0     4514
# 23.0     3337
# 24.0     3015
# 25.0     2711
# 26.0     2640
# 27.0     2986
# 28.0     3745
# 29.0     2673
# 30.0    51337
# Name: order_number, dtype: int64

# %%
grupby_order_people.plot(title='dias desde la orden anterior ',
                      x='days_since_prior_order',
                      y='order_number',
                      kind='bar',
                      xlabel='numero de dias',
                      ylabel='Cantidad de ordenes ',
                      legend=False )

plt.show()

# %%
print(grupby_order_people.sort_values())
# Out:
# days_since_prior_order
# 26.0     2640
# 29.0     2673
# 25.0     2711
# 27.0     2986
# 24.0     3015
# 23.0     3337
# 28.0     3745
# 22.0     4514
# 19.0     4939
# 18.0     4971
# 20.0     5302
# 17.0     5498
# 21.0     6448
# 16.0     6587
# 15.0     9416
# 0.0      9589
# 12.0    10658
# 11.0    11467
# 13.0    11737
# 10.0    13309
# 14.0    13992
# 9.0     16753
# 1.0     20179
# 8.0     25361
# 2.0     27138
# 5.0     30096
# 3.0     30224
# 4.0     31006
# 6.0     33930
# 7.0     44577
# 30.0    51337
# Name: order_number, dtype: int64

# %% [markdown]
# la mayoria de los usuarios compran su despensa cada 7 dias maximo y los minimos son 26 dias y hay un dato que seria para preguntar porque salen que cada 30 dias son muchos los usuarios que compran ese dia siendo el numero 1 en compras antes de cada 7 dias.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Excelente.
#
# </div>

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
wednesday_var =instacart_orders[instacart_orders['order_dow']==3]
saturday_var =instacart_orders[instacart_orders['order_dow']==6]

# %%
wednesday = wednesday_var.groupby('order_hour_of_day')['order_id'].count()
print(wednesday)
# Out:
# order_hour_of_day
# 0      373
# 1      215
# 2      106
# 3      101
# 4      108
# 5      170
# 6      643
# 7     1732
# 8     3125
# 9     4490
# 10    5026
# 11    5004
# 12    4688
# 13    4674
# 14    4774
# 15    5163
# 16    4976
# 17    4175
# 18    3463
# 19    2652
# 20    1917
# 21    1450
# 22    1154
# 23     718
# Name: order_id, dtype: int64

# %%
saturday= saturday_var.groupby('order_hour_of_day')['order_id'].count()
print(saturday)
# Out:
# order_hour_of_day
# 0      464
# 1      254
# 2      177
# 3      125
# 4      118
# 5      161
# 6      451
# 7     1619
# 8     3246
# 9     4311
# 10    4919
# 11    5116
# 12    5132
# 13    5323
# 14    5375
# 15    5188
# 16    5029
# 17    4295
# 18    3338
# 19    2610
# 20    1847
# 21    1473
# 22    1185
# 23     893
# Name: order_id, dtype: int64

# %%
concat_days = pd.concat([wednesday,saturday], axis = 1).reset_index()
print(concat_days )
#se hizo una variable para juntar dos variables hacer una por columna por eso axis=1
# Out:
#     order_hour_of_day  order_id  order_id
# 0                   0       373       464
# 1                   1       215       254
# 2                   2       106       177
# 3                   3       101       125
# 4                   4       108       118
# 5                   5       170       161
# 6                   6       643       451
# 7                   7      1732      1619
# 8                   8      3125      3246
# 9                   9      4490      4311
# 10                 10      5026      4919
# 11                 11      5004      5116
# 12                 12      4688      5132
# 13                 13      4674      5323
# 14                 14      4774      5375
# 15                 15      5163      5188
# 16                 16      4976      5029
# 17                 17      4175      4295
# 18                 18      3463      3338
# 19                 19      2652      2610
# 20                 20      1917      1847
# ...

# %%
concat_days.columns = ['hora_del_dia','Wednesday', 'Saturday']
#la variable anterior imprimimos por .columna que lo igualamos [con el titulo de la primera variable 
#y despues la segunda ]

print(concat_days)
# Out:
#     hora_del_dia  Wednesday  Saturday
# 0              0        373       464
# 1              1        215       254
# 2              2        106       177
# 3              3        101       125
# 4              4        108       118
# 5              5        170       161
# 6              6        643       451
# 7              7       1732      1619
# 8              8       3125      3246
# 9              9       4490      4311
# 10            10       5026      4919
# 11            11       5004      5116
# 12            12       4688      5132
# 13            13       4674      5323
# 14            14       4774      5375
# 15            15       5163      5188
# 16            16       4976      5029
# 17            17       4175      4295
# 18            18       3463      3338
# 19            19       2652      2610
# 20            20       1917      1847
# 21            21       1450      1473
# 22            22       1154      1185
# 23            23        718       893

# %%
concat_days.plot(title='DIFERENCIAS EN HORARIOS DE COMPRAS ENTRE LOS MIERCOLES Y SABADOS',
                      x='hora_del_dia',
                      y=['Wednesday','Saturday'],
                      kind='bar',
                      xlabel='horas del dia',
                      ylabel='cantidad de clientes')

plt.legend(['Wednesday','Saturday'])

plt.show()

# %% [markdown]
# la mayoria de personas compran entre las 10 am a las 4pm y los dias que mas compran son los sabados solamente los miercoles hay una considerablemente de personas que compran a las 10am

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy buen grafico, queda muy clara la diferencia de ambos dias.
#
# </div>

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %% [markdown]
# Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).

# %%
distribucion=instacart_orders.groupby('user_id')['order_id'].count().sort_values()

distribucion.plot(title='DISTRIBUCION DE PEDIDOS POR CLIENTES',
                  x='user_id',
                  y=['order_id'],
                  kind='hist',)

plt.xlabel('Pedidos por clientes')
plt.ylabel('Numero de ordenes')

plt.show()

# %% [markdown]
# Esto sugiere que la mayoría de los clientes han realizado pocos pedidos, posiblemente entre 1 y 6.
#
# Frecuencia Alta en Pedidos Bajos:
# La barra más alta se encuentra en el intervalo de 1 a 6 pedidos, con más de 100,000 clientes en esa categoría. Esto indica que hay muchos clientes que hacen pocos pedidos.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Recorda dejar tus conclusiones sobre esta extracción, podes comentar acerca de lo donde se produce el común de los resultados.</div>
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, perfecto.
#
# </div>

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
productos_populares = pd.merge(order_products,products, on='product_id')

# %%
veinte_productos=productos_populares.groupby(['product_id','product_name'])['order_id'].count().sort_values(ascending=False).head(20)

# %%
print(veinte_productos)
# Out:
# product_id  product_name
# 24852       BANANA                      66050
# 13176       BAG OF ORGANIC BANANAS      53297
# 21137       ORGANIC STRAWBERRIES        37039
# 21903       ORGANIC BABY SPINACH        33971
# 47209       ORGANIC HASS AVOCADO        29773
# 47766       ORGANIC AVOCADO             24689
# 47626       LARGE LEMON                 21495
# 16797       STRAWBERRIES                20018
# 26209       LIMES                       19690
# 27845       ORGANIC WHOLE MILK          19600
# 27966       ORGANIC RASPBERRIES         19197
# 22935       ORGANIC YELLOW ONION        15898
# 24964       ORGANIC GARLIC              15292
# 45007       ORGANIC ZUCCHINI            14584
# 39275       ORGANIC BLUEBERRIES         13879
# 49683       CUCUMBER KIRBY              13675
# 28204       ORGANIC FUJI APPLE          12544
# 5876        ORGANIC LEMON               12232
# 8277        APPLE HONEYCRISP ORGANIC    11993
# 40706       ORGANIC GRAPE TOMATOES      11781
# ...

# %%
veinte_productos.plot(kind='bar',title='20 productos más populares',ylabel='cantidad de ordenes')

plt.show()

# %% [markdown]
# aqui esta la lista de los productos mas populares los productos que tiene mas pedidos en sus ordenes siendo la BANANA como numero 1 con 66050 pieza y la 20 producto es ORGANIC GRAPE TOMATOES que se vende casi igual que ORGANIC YELLOW ONION

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Recorda que en este caso le agregaria valor graficar ese top 20 con un grafico de barras. Tener a mano el grafico hara mas amena y legible la experiencia del cliente.</div>
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, excelente grafico.
#
# </div>

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
order_products['add_to_cart_order'].mean()
# Out:
# 8.533887406554049

# %%
order_products['add_to_cart_order'].value_counts().plot(kind='hist',
                                                        title='Cantidad de articulos por orden',
                                                        bins=6,)

plt.ylabel('Cantida de Articulos')


plt.show()

# %% [markdown]
# sacamos una media de cuantos producto ingresan a una orden y son alrededore de 8 a 9 productos sin embargo graficamos para saber en que orden los usuarios ingresan mas productos a su carrito y son las primeras compras

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy bien.
#
#
# </div>

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
productos_populares
# Out:
#          order_id  product_id  add_to_cart_order  reordered  \
# 0         2141543       11440               17.0          0
# 1          147172       11440                7.0          1
# 2         3341719       11440                4.0          1
# 3         1938779       11440                8.0          1
# 4         1728338       11440               23.0          0
# ...           ...         ...                ...        ...
# 4545002    267402       45226               14.0          0
# 4545003   2621676       25201               10.0          0
# 4545004    937623       49153                2.0          0
# 4545005    532895        8182                1.0          0
# 4545006   3132243       40024                1.0          0
#
#                                product_name  aisle_id  department_id
# 0            CHICKEN BREAST TENDERS BREADED       129              1
# 1            CHICKEN BREAST TENDERS BREADED       129              1
# ...

# %%
veinte_frecuentes = productos_populares[productos_populares['reordered']==1]
print(veinte_frecuentes)
#'reordered': 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# Out:
#          order_id  product_id  add_to_cart_order  reordered  \
# 1          147172       11440                7.0          1
# 2         3341719       11440                4.0          1
# 3         1938779       11440                8.0          1
# 7          331884       11440                5.0          1
# 8         1869056       11440               12.0          1
# ...           ...         ...                ...        ...
# 4544981   2421451       10661                2.0          1
# 4544983   1215763       14192                7.0          1
# 4544993   1817765       16672               11.0          1
# 4544994   1993036       22264                3.0          1
# 4545000   1525782       18946                3.0          1
#
#                                              product_name  aisle_id  \
# 1                          CHICKEN BREAST TENDERS BREADED       129
# 2                          CHICKEN BREAST TENDERS BREADED       129
# ...

# %%
top_20=veinte_frecuentes.groupby(['product_id','product_name'])['order_id'].count().sort_values(ascending=False).head(20)

# %%
print(top_20 )
# Out:
# product_id  product_name
# 24852       BANANA                      55763
# 13176       BAG OF ORGANIC BANANAS      44450
# 21137       ORGANIC STRAWBERRIES        28639
# 21903       ORGANIC BABY SPINACH        26233
# 47209       ORGANIC HASS AVOCADO        23629
# 47766       ORGANIC AVOCADO             18743
# 27845       ORGANIC WHOLE MILK          16251
# 47626       LARGE LEMON                 15044
# 27966       ORGANIC RASPBERRIES         14748
# 16797       STRAWBERRIES                13945
# 26209       LIMES                       13327
# 22935       ORGANIC YELLOW ONION        11145
# 24964       ORGANIC GARLIC              10411
# 45007       ORGANIC ZUCCHINI            10076
# 49683       CUCUMBER KIRBY               9538
# 28204       ORGANIC FUJI APPLE           8989
# 8277        APPLE HONEYCRISP ORGANIC     8836
# 39275       ORGANIC BLUEBERRIES          8799
# 5876        ORGANIC LEMON                8412
# 49235       ORGANIC HALF & HALF          8389
# ...

# %%
top_20.plot(kind='bar',title='20 productos con mayor frecuencia',
            x= ['product_name','product_id'],
            y='order_id', 
            ylabel='cantidad de ordenes',
            xlabel= 'ID y nombre del Producto',
           legend= False )

plt.show()

# %% [markdown]
# aqui son los productos que mas frecuentes piden los clientes ya que se filtra solamente los clientes que ya han llevado en su carrito esos productos mas de una vez.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Elpidio, te dejo una guia de como continuar en los siguientes ejercicios. Has hecho un muy buen trabajo.
#
#
# Para resolverlo filtra los artículos reordenados, en primer lugar filtramos la tabla de pedidos (order_products) para quedarnos solo con los que tienen el campo reordered igual a 1. Esto significa que solo tomamos los registros donde se volvió a pedir el producto.
#
# Luego, combinamos la tabla filtrada con la tabla de productos (products) usando el identificador común product_id. Ahora tenemos información de ambos lados como nombre del producto, cantidad pedida, etc.
#
# Para encontrar los mas populares agrupamos los datos por product_id y product_name. Esto nos permite contar cuántas veces se pidió cada producto. Luego, ordenamos esta lista de manera descendente, de mayor a menor cantidad de pedidos.
#
# Finalmente, toma solo los primeros 20 productos de este ranking</div>
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, excelee extraccion.
#
# </div>

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
combined_df = pd.merge(order_products, products, on='product_id')
combined_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  \
# 0   2141543       11440               17.0          0
# 1    147172       11440                7.0          1
# 2   3341719       11440                4.0          1
# 3   1938779       11440                8.0          1
# 4   1728338       11440               23.0          0
#
#                      product_name  aisle_id  department_id
# 0  CHICKEN BREAST TENDERS BREADED       129              1
# 1  CHICKEN BREAST TENDERS BREADED       129              1
# 2  CHICKEN BREAST TENDERS BREADED       129              1
# 3  CHICKEN BREAST TENDERS BREADED       129              1
# 4  CHICKEN BREAST TENDERS BREADED       129              1

# %%
veces_producto = combined_df.groupby([ 'product_id', 'reordered', 'product_name'])['order_id'].count()
print(veces_producto)
# Out:
# product_id  reordered  product_name
# 1           0          CHOCOLATE SANDWICH COOKIES                         122
#             1          CHOCOLATE SANDWICH COOKIES                         158
# 2           0          ALL-SEASONS SALT                                    11
# 3           0          ROBUST GOLDEN UNSWEETENED OOLONG TEA                11
#             1          ROBUST GOLDEN UNSWEETENED OOLONG TEA                31
#                                                                          ...
# 49692       1          ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR      5
# 49693       0          SPRING WATER BODY WASH                              14
#             1          SPRING WATER BODY WASH                              11
# 49694       0          BURRITO- STEAK & CHEESE                              6
#             1          BURRITO- STEAK & CHEESE                              3
# Name: order_id, Length: 79992, dtype: int64

# %%
veces_producto = combined_df.groupby([ 'product_id', 'product_name'])['reordered'].mean().sort_values(ascending=False).head(10)
print(veces_producto)
# Out:
# product_id  product_name
# 14721       BONE STRENGTH TAKE CARE                                             1.0
# 20949       VANILLA SANDWICH COOKIES                                            1.0
# 6723        PALMIERS- PETITE                                                    1.0
# 6732        NATURALLY SPARKLING MINERAL WATER                                   1.0
# 45088       CALIFORNIA DILL POLLEN & GARLIC GOAT CHEESE & OLIVE OIL INFUSION    1.0
# 45078       POMEGRANATEA                                                        1.0
# 21016       PARCHMENT LINED 8 IN X 3.75 IN X 2.5 IN PANS                        1.0
# 21005       PEANUT BUTTER PIE ICE CREAM                                         1.0
# 35192       CHOCOLATE SOY MILK SINGLES                                          1.0
# 35197       MOCHA CHOCOLATE CHIP  ORGANIC NON-DAIRY FROZEN DESSERT              1.0
# Name: reordered, dtype: float64

# %% [markdown]
# a pesar de que la banana es el producto mas vendido lo que la gente pide y vuelve a pedir es el BONE STRENGTH TAKE CARE  asi como los demas productos que se ven esos productos tiene un 100% que se vuelven a pedir.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# En este caso debemos combinar ambas tablas (`order_products` y `products`). Esto crea una nueva tabla con información combinada, como nombre del producto y si se volvió a pedir (de la tabla de pedidos).
#
# Luego, agrupamos (con un groupby) la información por `product_id` y `product_name`. En cada grupo, calculamos la media del campo reordered. Recuerda que este campo indica si un producto se volvió a pedir (1) o no (0). Entonces, el promedio nos revela la tasa de reorden para cada producto: qué porcentaje de veces se volvió a pedir en general.
#
# Por último,  pode ordenar la nueva tabla (`nombre_nueva_tabla`) por product_id. Esto nos permite ver la tasa de reorden de cada producto, ordenados de mayor a menor.</div>
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, muy bueno.
#
# </div>

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
combined_id = pd.merge(order_products, instacart_orders , on='order_id', how='inner')
print(combined_id)
# Out:
#          order_id  product_id  add_to_cart_order  reordered  user_id  \
# 0         2141543       11440               17.0          0    58454
# 1         2141543       31869               15.0          1    58454
# 2         2141543       30233                9.0          1    58454
# 3         2141543       27966               20.0          1    58454
# 4         2141543       13176                2.0          1    58454
# ...           ...         ...                ...        ...      ...
# 4545002   1790509       43739                1.0          1    60894
# 4545003   1274005       38275                1.0          1    32958
# 4545004    812418       46149                1.0          1   130466
# 4545005   2666881         196                1.0          1    33946
# 4545006   1461911       33198                1.0          1    54019
#
#          order_number  order_dow  order_hour_of_day  days_since_prior_order
# ...

# %%
combined_id.groupby('user_id')['reordered'].mean().sort_values(ascending=False).head(10)
# Out:
# user_id
# 137587    1.0
# 173474    1.0
# 13918     1.0
# 62300     1.0
# 62307     1.0
# 96301     1.0
# 62312     1.0
# 48616     1.0
# 62316     1.0
# 191162    1.0
# Name: reordered, dtype: float64

# %% [markdown]
# los ususarios que siempre estan reordenando y haciendo pedido son los que estan con 1.0 que son los usuarios que 100% hacen su reorden cada 7 15 o 30 dias segun los analisis anteriores.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
#
# Primero, combinamos las tablas order_products y orders. Esto lo hacemos para que el registro de pedido tiene detalles tanto sobre los productos pedidos como sobre el usuario que realizó el pedido.
#
# Luego centrate en la columna reordered dentro de la tabla fusionada. La columna nos dicesi un producto fue reordenado (marcado como 1) o no (marcado como 0) dentro de ese pedido específico.
#
# Agrupa los datos por user_id (para analizar los pedidos de cada usuario por separado). Para cada grupo de usuarios, calculamos el valor promedio de la columna reordered. Y ahi tendras el porcentaje.
#
# Al final ordena la tabla para observar cuales son los productos con mayor frecuencia.</div>
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.
#
# </div>

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
primer_producto = productos_populares[productos_populares['add_to_cart_order']==1]
print(primer_producto)
#'add_to_cart_order': el orden secuencial en el que se añadió cada artículo en el carrito.
# Out:
#          order_id  product_id  add_to_cart_order  reordered  \
# 6         1463503       11440                1.0          0
# 17        2201430       11440                1.0          1
# 21        1036054       11440                1.0          1
# 50        3008652       11440                1.0          1
# 62        2946144       11440                1.0          1
# ...           ...         ...                ...        ...
# 4544972   1518168       16952                1.0          0
# 4544977   1776450       21507                1.0          0
# 4544995   2333206       25467                1.0          0
# 4545005    532895        8182                1.0          0
# 4545006   3132243       40024                1.0          0
#
#                                      product_name  aisle_id  department_id
# 6                  CHICKEN BREAST TENDERS BREADED       129              1
# 17                 CHICKEN BREAST TENDERS BREADED       129              1
# ...

# %%
primeros_20 = primer_producto.groupby(['product_id','product_name'])['order_id'].count().sort_values(ascending=False).head(20)
print(primeros_20)
# Out:
# product_id  product_name
# 24852       BANANA                         15562
# 13176       BAG OF ORGANIC BANANAS         11026
# 27845       ORGANIC WHOLE MILK              4363
# 21137       ORGANIC STRAWBERRIES            3946
# 47209       ORGANIC HASS AVOCADO            3390
# 21903       ORGANIC BABY SPINACH            3336
# 47766       ORGANIC AVOCADO                 3044
# 19660       SPRING WATER                    2336
# 16797       STRAWBERRIES                    2308
# 27966       ORGANIC RASPBERRIES             2024
# 44632       SPARKLING WATER GRAPEFRUIT      1914
# 49235       ORGANIC HALF & HALF             1797
# 47626       LARGE LEMON                     1737
# 196         SODA                            1733
# 38689       ORGANIC REDUCED FAT MILK        1397
# 26209       LIMES                           1370
# 12341       HASS AVOCADOS                   1340
# 5785        ORGANIC REDUCED FAT 2% MILK     1310
# 27086       HALF & HALF                     1309
# ...

# %%
primeros_20.plot(kind='bar',title='Primeros 20 Productos que ponen en Carrito',
            x= ['product_name','product_id'],
            y='order_id', 
            ylabel='cantidad de ordenes',
            xlabel= 'ID y nombre del Producto',
           legend= False )

plt.show()

# %% [markdown]
# aqui miramos solo los produtos que han puesto como #1 en su carrito ahora si lo primero que piden

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
#
# En primer lugar combina ambas tablas, tanto `order_products` y `products`, de igual manera que nates para tener el nombre y orden que se añadio al carro.
#
# Despues filtra esos registros solo con aquellos donde el producto fue añadido como el primero en el carrito (valor 1 en la columna `add_to_cart_order`) -que es lo que haces al principio pero sin el merge-.
#
# Agrupa la información por `product_id` y `product_name`. En cada grupo, **conta** cuantas veces aparece ese producto como el primero en el carrito. Esto nos da una idea de la popularidad de cada producto al iniciar compras. Luego ordena la tabla final.</div>
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, excelente grafico.
#
# </div>

# %% [markdown]
# ### Conclusion general del proyecto:

# %% [markdown]
# en este proyecto lo que encontramos fueron valores ausentes y duplicados los cuales empezando hacer limpieza antes de analizarlos asi como visualizar que habia datos ausentes no se debian de cambiar ni modificar ya que son datos necesarios como en el caso del archivo orders y la columna days_since_prior_order ya que es una columna que si necesita esos datos y es de suma importancia no cambiarlos, asi como la pregunta de ¿Todos los pedidos con valores ausentes tienen más de 64 producto? y si todos los datos ausentes tienen mas de 64 productos otro dato que se tenia que analizar los datos ausentes despues de toda la limpieza empezamos con los analisis sobre el estudio de la tienda.

# %% [markdown]
# conclusion para la empresa:
#
# 1.-Las horas que mas compra la gente es de 10am a 4pm siendo los Domingos y Lunes los dias que hacen sus compras.
# 2.-Los clientes compran con mayor frecuencia cada 30 dias en segundo lugar cada 7 dias y cada 14 dias.
# 3.-Entre miercoles y sabado la mayoria de la gente compra los sabados de 10am a 4pm con excepcion de las 10am ahi compran mas los miercoles que los sabados.
# 3.-En el intervalo de 1 a 5 pedidos, hay mas de 100,000 clientes en haciendo pedidos  ya despues 6 pedidos van bajando la candidad de clientes que hacen mas pedidos.
# 4.-hay una lista de 20 productos mas vendidos que es la BANANA Y las BOLSAS para las BANANAS
# 5.-la gente normalmente compra de 8 a 9 articulos sacando la media sin embargo en la grafica vemos que hay cierta cantidad de personas que compras mas de 40 articulos.
# 6.-Tambien hay 20 articulos que mas se vuelven a comprar que son la BANANA  y sus BOLSAS sin embargo vemos en la grafica vemos que en 9no lugar esta ORGANIC RASPBERRIES y cambia a comparacion de los mas vendidos ya que este preoducto es uno de los que se vuelven a comprar despues de su primer compra y un ejemplo ORGANIC WHOLE MILK a pesar que es un producto que mas se venden no lo vuelven a comprar con tanta frecuencia.
# 7.-los productos que vuelven a pedir un ejemplo es BONE STRENGHT TAKE CARE es un producto categorizado con el 100% de que cada vez que hacen sus despensas entra en su carrito de compras y asi como varios productos mas que estan con 1. en el apartado [C3] se podra visualizar mas informacion al respecto
# 8.-Los usuarios que siempre hacen pedidos son los que en la dia sale con el 100% o en este casi 1 como el usuario 137587 este usuario asi como otros son los que han echo mas pedidos y son los que con mas frecuencia compran mayor informacion de usuarios con el mismo porcentaje en el apartado [C4]
# 9.-el primer Producto que se agrega al carrito y el mas indispensabe son las BANANAS y sus BOLSAS y el tercero es el ORGANIC WHOLE MILK y con este ultimo mensionado me refiero a que es el que tercer producto que compran en su primer compra y no lo compran con frecuencia, a esto me refiero que todos los usuarios en su primer compra agregaron como tercer lugar el ORGANIC WHOLE MILK.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Recorda realizar una conclusion general orientada al cliente. Esta debe contener todo lo que se hizo en el proyecto de forma enumerada o items.
#
# Desde la carga e importacion, pasando por los cambios realizado (Y el porque de esas decisiones). Agregando lo que se hizo en cada seccion a modo resumen y las conclusiones del  trabajo.
#
# Sirve como resumen de lo realizado en cada proyecto.</div>
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, muy  buena conclusion general.
#
# </div>
